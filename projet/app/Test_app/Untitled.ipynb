# %%
import pandas as pd
import yfinance as yf
import yahoofinancials
import numpy as np
import math
import matplotlib

# %%
def get_tickertop10(fichiercsv):
    Tabl = pd.read_csv(fichiercsv, sep=';', index_col=0)
    return Tabl
tabl = get_tickertop10('donnees_top10_1.csv')

# %%
tabl
# Out:
#     Date_debut    Date_fin          1           2             3             4  \
# 1   2010-01-01  2010-04-08     DDC.TO   BPO-PR.TO     BPY-UN.TO     BEP-UN.TO
# 2   2010-04-01  2010-07-08     BTE.TO      ABX.TO        ZAG.TO        ZWB.TO
# 3   2010-07-01  2010-10-08     BLX.TO   CHE-UN.TO        BTE.TO        CLS.TO
# 4   2010-10-01  2011-01-08      CM.TO      CNR.TO        CNQ.TO         CP.TO
# 5   2011-01-01  2011-04-08   GIB-A.TO      CAE.TO        ALA.TO      ATD-B.TO
# 6   2011-04-01  2011-07-08     BAD.TO   BYD-UN.TO         CU.TO        BMO.TO
# 7   2011-07-01  2011-10-08   GIB-A.TO     D-UN.TO        ZWB.TO        ZHY.TO
# 8   2011-10-01  2012-01-08   CCL-B.TO    BAM-A.TO        DGC.TO     CRT-UN.TO
# 9   2012-01-01  2012-04-08  BEI-UN.TO      ZDY.TO      BBD-B.TO      CTC-A.TO
# 10  2012-04-01  2012-07-08     AGU.TO      DOL.TO        AFN.TO         BB.TO
# 11  2012-07-01  2012-10-08   BAM-A.TO    BBD-B.TO        ARX.TO      CCL-B.TO
# 12  2012-10-01  2013-01-08     CSU.TO      ZEA.TO        ZUE.TO        ZSP.TO
# 13  2013-01-01  2013-04-08     ZIC.TO      CSU.TO        ZHY.TO        ZPR.TO
# 14  2013-04-01  2013-07-08     CSU.TO      ZCM.TO        CNU.TO        ZIC.TO
# 15  2013-07-01  2013-10-08     CGX.TO   CAR-UN.TO      DII-B.TO        AFN.TO
# 16  2013-10-01  2014-01-08     CAE.TO      AGI.TO        ARX.TO        BCE.TO
# 17  2014-01-01  2014-04-08     BAD.TO    CCL-B.TO        DDC.TO        BMO.TO
# 18  2014-04-01  2014-07-08     BAD.TO      DDC.TO        BNP.TO      CCL-B.TO
# 19  2014-07-01  2014-10-08     BAD.TO      BNS.TO        BMO.TO        DDC.TO
# 20  2014-10-01  2015-01-08   GIB-A.TO      AIM.TO     BYD-UN.TO        ALA.TO
# 21  2015-01-01  2015-04-08     ARX.TO    DII-B.TO        ZUE.TO      CCL-B.TO
# 22  2015-04-01  2015-07-08   GIB-A.TO      BAD.TO        BMO.TO        CEF.TO
# 23  2015-07-01  2015-10-08   ATD-B.TO   BEI-UN.TO        DGC.TO        CAS.TO
# 24  2015-10-01  2016-01-08     CCO.TO      CIX.TO        AAV.TO        CEU.TO
# 25  2016-01-01  2016-04-08     DDC.TO      DGC.TO         DH.TO      CCL-B.TO
# 26  2016-04-01  2016-07-08   AP-UN.TO      ZDY.TO        CGX.TO        ARX.TO
# 27  2016-07-01  2016-10-08   BAM-A.TO   BBU-UN.TO     BIP-UN.TO   BPO-PR-A.TO
# 28  2016-10-01  2017-01-08  BEP-UN.TO   BBU-UN.TO     BIP-UN.TO   BPO-PR-A.TO
# 29  2017-01-01  2017-04-08     CVE.TO      ALA.TO        AFN.TO        AQN.TO
# 30  2017-04-01  2017-07-08     BCB.TO      ZAG.TO        ZWB.TO        ZHY.TO
# 31  2017-07-01  2017-10-08   BAM-A.TO      CIX.TO        CPG.TO     CSH-UN.TO
# 32  2017-10-01  2018-01-08     AIM.TO      ALA.TO        CAE.TO      ATD-B.TO
# 33  2018-01-01  2018-04-08     CAE.TO      CPG.TO        AGU.TO        BAD.TO
# 34  2018-04-01  2018-07-08  EIT-UN.TO   BIP-UN.TO   BPO-PR-A.TO     BPY-UN.TO
# 35  2018-07-01  2018-10-08     AIM.TO      BCB.TO        DSG.TO     CUF-UN.TO
# 36  2018-10-01  2019-01-08  BYD-UN.TO    GIB-A.TO     BBU-UN.TO      BAM-A.TO
# 37  2019-01-01  2019-04-08     CCO.TO      ABX.TO     CAR-UN.TO        BMO.TO
# 38  2019-04-01  2019-07-08     CAE.TO      CIX.TO      BBD-B.TO        AYA.TO
# 39  2019-07-01  2019-10-08     CSU.TO      CWB.TO        ZEA.TO        ZPR.TO
# 40  2019-10-01  2020-01-08     CNU.TO      CIX.TO        AEM.TO        ZHY.TO
# 41  2020-01-01  2020-04-08      BINGO       BINGO         BINGO         BINGO
#
#              5           6           7           8             9          10
# 1       AAV.TO      DGC.TO      AFN.TO       BB.TO        CEF.TO   CAR-UN.TO
# 2       ZHY.TO      ZPR.TO      ZSP.TO      ZCN.TO        ZCS.TO      ZDY.TO
# 3       BIR.TO      ARX.TO   CSH-UN.TO      ABX.TO        CAS.TO    CCL-B.TO
# 4    REF-UN.TO      ZIC.TO      ZEA.TO      ZUE.TO        ZSP.TO      ZCN.TO
# 5       AGI.TO      ARX.TO      AQN.TO      BTO.TO      AP-UN.TO      AIF.TO
# 6       CWB.TO      BNS.TO    BINGO.TO    BINGO.TO      BINGO.TO    BINGO.TO
# 7       ZPR.TO      ZLB.TO       AC.TO      CEU.TO        CGG.TO   DRG-UN.TO
# 8       BNS.TO      BMO.TO      CPX.TO      BAD.TO     EIT-UN.TO   BEI-UN.TO
# 9        CU.TO      CWB.TO      BAD.TO      ARX.TO      BINGO.TO    BINGO.TO
# 10      AAV.TO      CEF.TO      ZAG.TO      ZWB.TO      BINGO.TO    BINGO.TO
# 11       DH.TO      BAD.TO    BINGO.TO    BINGO.TO      BINGO.TO    BINGO.TO
# 12      ZCN.TO      ZCS.TO    CTC-A.TO       CU.TO        CWB.TO    AP-UN.TO
# 13      ZLB.TO      ZCM.TO    CTC-A.TO      AFN.TO        AAV.TO      CNQ.TO
# 14      ZEA.TO      ZUE.TO      ZSP.TO       AC.TO      CTC-A.TO      CNQ.TO
# 15      CIX.TO   DRG-UN.TO     D-UN.TO      CNR.TO        CGG.TO      CEU.TO
# 16    AP-UN.TO      ZHY.TO      ZPR.TO      ZLB.TO        ZCM.TO    GIB-A.TO
# 17      BNS.TO   BYD-UN.TO    BINGO.TO    BINGO.TO      BINGO.TO    BINGO.TO
# 18      BNS.TO    CEF-A.TO      BMO.TO   DRG-UN.TO      BINGO.TO    BINGO.TO
# 19    CCL-B.TO    BINGO.TO    BINGO.TO    BINGO.TO      BINGO.TO    BINGO.TO
# 20      ARX.TO      AYA.TO    ACO-X.TO       AC.TO        ARE.TO      AIF.TO
# 21      AAV.TO      AFN.TO      ZSP.TO      ZCN.TO        ZCS.TO      ZDY.TO
# 22      CGG.TO    BAM-A.TO   BBU-UN.TO   BIP-UN.TO   BPO-PR-A.TO    BINGO.TO
# 23   CRT-UN.TO       CR.TO      ZCN.TO      ZCS.TO        ZDY.TO       AC.TO
# 24   CAR-UN.TO      AFN.TO      ZAG.TO      ZWB.TO        ZHY.TO      ZPR.TO
# 25       BB.TO      AFN.TO      CPX.TO      AAV.TO        ZAG.TO    BAM-A.TO
# 26      CIX.TO      ZUE.TO      ZSP.TO      ZCN.TO        ZCS.TO       CP.TO
# 27   CRT-UN.TO       DH.TO      BMO.TO      BNS.TO      CCL-B.TO      BAD.TO
# 28   BPY-UN.TO      AIM.TO    ATD-B.TO      BCE.TO        ALA.TO      ABX.TO
# 29      ARE.TO    AP-UN.TO      AIM.TO      AAV.TO        AEM.TO      AGI.TO
# 30      ZPR.TO   CRT-UN.TO      AAV.TO      CPG.TO         CR.TO       CP.TO
# 31      CGC.TO       DH.TO      BCB.TO      CGG.TO      DII-B.TO   CRT-UN.TO
# 32    AX-UN.TO      BIR.TO      ZAG.TO      ZHY.TO        ZDY.TO      ZCS.TO
# 33      CAS.TO      CSU.TO      ZCM.TO      ZIC.TO        ZEA.TO      ZUE.TO
# 34   BEP-UN.TO      DSG.TO      CFP.TO      BAD.TO        CIX.TO      ZLB.TO
# 35      CPG.TO      AYA.TO      CEE.TO      CIX.TO        CNU.TO      AIF.TO
# 36      CGG.TO      CEF.TO    BBD-B.TO    AP-UN.TO      BINGO.TO    BINGO.TO
# 37      BNS.TO    BINGO.TO    BINGO.TO    BINGO.TO      BINGO.TO    BINGO.TO
# 38      AIM.TO    AX-UN.TO      ARE.TO   DRG-UN.TO        CPX.TO       CG.TO
# 39      ZLB.TO      ZCM.TO      ZIC.TO    CTC-A.TO         CU.TO   REF-UN.TO
# 40      ZPR.TO      ZLB.TO      ZCM.TO      AFN.TO        AAV.TO      CNQ.TO
# 41       BINGO       BINGO       BINGO       BINGO         BINGO       BINGO
